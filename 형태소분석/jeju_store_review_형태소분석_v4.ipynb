# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/빅콘테스트/01.데이터수집 및 탐색/data/review_data/df2_형태소분석.csv', index_col=0)

df.head()
# Out:
#      name                         address category  \
# 0    번네식당  제주 서귀포시 안덕면 화순리 1810-11번지 번네식당       한식
# 1    번영가든            제주 제주시 봉개동 1385번지 1층       한식
# 2    번영김밥               제주 제주시 봉개동 1902번지     종합분식
# 3   번영로뷔페            제주 제주시 도련일동 2574-1번지     한식뷔페
# 4  번영로휴게소                제주 제주시 봉개동 545번지    일반휴게소
#
#                                              reviews  \
# 0  제주도 여행 하면서 처음 먹어본 갈치조림! 순살이라서 더 먹기 편했어요^^ 여행객이...
# 1  포장했는데 맛있었어용가격대비 좋아요좋아요~^^주차도 편하고 음식맛도있어요맛있게 먹었...
# 2  김밥 맛있어요일가면서 가끔 들리는 장소 맛도짱 입니다.소고기2줄은 밖에서 먹고,멸추...
# 3  오늘은 집근처에 있는 뷔페집 왔어요\n소개로 오게 되었는데\n오픈하신지 2개월 되었...
# 4  굿좋아요새벽에 지나가다 들렀는데 좋네요좋아요~사이프러스로 골프 치러 가는 길에 김밥...
#
#                                           pos_tokens      예약_유      예약_무  \
# 0  ['갈치', '조림', '여행객', '자락', '시간대', '분도', '성게', '...  0.322581  0.677419
# 1  ['포장', '가격', '대비', '주차', '식사', '반찬', '식혜', '가정...  0.000000  0.000000
# 2  ['김밥', '장소', '소고기', '사진', '실물', '소고기', '김밥', '...  0.000000  1.000000
# ...

# %%
df.loc[(df['예약_무'] == 0) & (df['예약_유'] == 0), ['예약_무', '예약_유']] = np.nan

# %%
df.head()
# Out:
#      name                         address category  \
# 0    번네식당  제주 서귀포시 안덕면 화순리 1810-11번지 번네식당       한식
# 1    번영가든            제주 제주시 봉개동 1385번지 1층       한식
# 2    번영김밥               제주 제주시 봉개동 1902번지     종합분식
# 3   번영로뷔페            제주 제주시 도련일동 2574-1번지     한식뷔페
# 4  번영로휴게소                제주 제주시 봉개동 545번지    일반휴게소
#
#                                              reviews  \
# 0  제주도 여행 하면서 처음 먹어본 갈치조림! 순살이라서 더 먹기 편했어요^^ 여행객이...
# 1  포장했는데 맛있었어용가격대비 좋아요좋아요~^^주차도 편하고 음식맛도있어요맛있게 먹었...
# 2  김밥 맛있어요일가면서 가끔 들리는 장소 맛도짱 입니다.소고기2줄은 밖에서 먹고,멸추...
# 3  오늘은 집근처에 있는 뷔페집 왔어요\n소개로 오게 되었는데\n오픈하신지 2개월 되었...
# 4  굿좋아요새벽에 지나가다 들렀는데 좋네요좋아요~사이프러스로 골프 치러 가는 길에 김밥...
#
#                                           pos_tokens      예약_유      예약_무  \
# 0  ['갈치', '조림', '여행객', '자락', '시간대', '분도', '성게', '...  0.322581  0.677419
# 1  ['포장', '가격', '대비', '주차', '식사', '반찬', '식혜', '가정...       NaN       NaN
# 2  ['김밥', '장소', '소고기', '사진', '실물', '소고기', '김밥', '...  0.000000  1.000000
# ...

# %%
df.columns
# Out:
# Index(['name', 'address', 'category', 'reviews', 'pos_tokens', '예약_유', '예약_무',
#        '포장_배달_유무', '바로_입장', '10분_이내', '30분_이내', '30분_이상', '1시간_이상', '2시간_이상',
#        '데이트', '친목', '나들이', '여행', '일상', '기념일', '회식', '가족모임', '비즈니스', '연인_배우자',
#        '친구', '지인_동료', '혼자', '아이', '부모님', '반려동물', '친척_형제', '기타', 'top_tokens'],
#       dtype='object')

# %%
df.loc[(df['연인_배우자'] == 0) & (df['친구'] == 0) & (df['지인_동료'] == 0) & (df['혼자'] == 0)
& (df['아이'] == 0) & (df['부모님'] == 0) & (df['반려동물'] == 0) & (df['친척_형제'] == 0) & (df['기타'] == 0), ['연인_배우자',
       '친구', '지인_동료', '혼자', '아이', '부모님', '반려동물', '친척_형제', '기타']] = np.nan

# %%
df[['연인_배우자',
       '친구', '지인_동료', '혼자', '아이', '부모님', '반려동물', '친척_형제', '기타']].head()
# Out:
#      연인_배우자        친구     지인_동료   혼자        아이       부모님  반려동물     친척_형제   기타
# 0  0.526316  0.210526  0.026316  0.0  0.096491  0.105263   0.0  0.035088  0.0
# 1       NaN       NaN       NaN  NaN       NaN       NaN   NaN       NaN  NaN
# 2  0.500000  0.000000  0.500000  0.0  0.000000  0.000000   0.0  0.000000  0.0
# 3  0.000000  0.000000  0.000000  1.0  0.000000  0.000000   0.0  0.000000  0.0
# 4       NaN       NaN       NaN  NaN       NaN       NaN   NaN       NaN  NaN

# %%
df.loc[(df['바로_입장'] == 0) & (df['10분_이내'] == 0) & (df['30분_이내'] == 0) & (df['30분_이상'] == 0)
& (df['1시간_이상'] == 0) & (df['2시간_이상'] == 0), ['바로_입장', '10분_이내', '30분_이내', '30분_이상', '1시간_이상', '2시간_이상']] = np.nan

# %%
df.head()
# Out:
#      name                         address category  \
# 0    번네식당  제주 서귀포시 안덕면 화순리 1810-11번지 번네식당       한식
# 1    번영가든            제주 제주시 봉개동 1385번지 1층       한식
# 2    번영김밥               제주 제주시 봉개동 1902번지     종합분식
# 3   번영로뷔페            제주 제주시 도련일동 2574-1번지     한식뷔페
# 4  번영로휴게소                제주 제주시 봉개동 545번지    일반휴게소
#
#                                              reviews  \
# 0  제주도 여행 하면서 처음 먹어본 갈치조림! 순살이라서 더 먹기 편했어요^^ 여행객이...
# 1  포장했는데 맛있었어용가격대비 좋아요좋아요~^^주차도 편하고 음식맛도있어요맛있게 먹었...
# 2  김밥 맛있어요일가면서 가끔 들리는 장소 맛도짱 입니다.소고기2줄은 밖에서 먹고,멸추...
# 3  오늘은 집근처에 있는 뷔페집 왔어요\n소개로 오게 되었는데\n오픈하신지 2개월 되었...
# 4  굿좋아요새벽에 지나가다 들렀는데 좋네요좋아요~사이프러스로 골프 치러 가는 길에 김밥...
#
#                                           pos_tokens      예약_유      예약_무  \
# 0  ['갈치', '조림', '여행객', '자락', '시간대', '분도', '성게', '...  0.322581  0.677419
# 1  ['포장', '가격', '대비', '주차', '식사', '반찬', '식혜', '가정...       NaN       NaN
# 2  ['김밥', '장소', '소고기', '사진', '실물', '소고기', '김밥', '...  0.000000  1.000000
# ...

# %%
df.columns
# Out:
# Index(['name', 'address', 'category', 'reviews', 'pos_tokens', '예약_유', '예약_무',
#        '포장_배달_유무', '바로_입장', '10분_이내', '30분_이내', '30분_이상', '1시간_이상', '2시간_이상',
#        '데이트', '친목', '나들이', '여행', '일상', '기념일', '회식', '가족모임', '비즈니스', '연인_배우자',
#        '친구', '지인_동료', '혼자', '아이', '부모님', '반려동물', '친척_형제', '기타', 'top_tokens'],
#       dtype='object')

# %%
df = df[['name', 'address', 'category', 'reviews', 'pos_tokens', 'top_tokens', '예약_유', '예약_무',
       '포장_배달_유무', '바로_입장', '10분_이내', '30분_이내', '30분_이상', '1시간_이상', '2시간_이상',
       '데이트', '친목', '나들이', '여행', '일상', '기념일', '회식', '가족모임', '비즈니스', '연인_배우자',
       '친구', '지인_동료', '혼자', '아이', '부모님', '반려동물', '친척_형제', '기타']]

# %%
df.head()
# Out:
#      name                         address category  \
# 0    번네식당  제주 서귀포시 안덕면 화순리 1810-11번지 번네식당       한식
# 1    번영가든            제주 제주시 봉개동 1385번지 1층       한식
# 2    번영김밥               제주 제주시 봉개동 1902번지     종합분식
# 3   번영로뷔페            제주 제주시 도련일동 2574-1번지     한식뷔페
# 4  번영로휴게소                제주 제주시 봉개동 545번지    일반휴게소
#
#                                              reviews  \
# 0  제주도 여행 하면서 처음 먹어본 갈치조림! 순살이라서 더 먹기 편했어요^^ 여행객이...
# 1  포장했는데 맛있었어용가격대비 좋아요좋아요~^^주차도 편하고 음식맛도있어요맛있게 먹었...
# 2  김밥 맛있어요일가면서 가끔 들리는 장소 맛도짱 입니다.소고기2줄은 밖에서 먹고,멸추...
# 3  오늘은 집근처에 있는 뷔페집 왔어요\n소개로 오게 되었는데\n오픈하신지 2개월 되었...
# 4  굿좋아요새벽에 지나가다 들렀는데 좋네요좋아요~사이프러스로 골프 치러 가는 길에 김밥...
#
#                                           pos_tokens  \
# 0  ['갈치', '조림', '여행객', '자락', '시간대', '분도', '성게', '...
# 1  ['포장', '가격', '대비', '주차', '식사', '반찬', '식혜', '가정...
# 2  ['김밥', '장소', '소고기', '사진', '실물', '소고기', '김밥', '...
# 3  ['오늘', '뷔페', '소개', '개월', '인지', '일단', '차편', '뷔페...
# 4  ['새벽', '사이프러스', '골프', '김밥', '간식', '거리', '애용', ...
#
# ...

# %%
df.to_csv('/content/drive/MyDrive/빅콘테스트/01.데이터수집 및 탐색/code/EDA/예진/data/jeju_store_keyword_v3.csv')

# %%
df.to_csv('/content/drive/MyDrive/빅콘테스트/01.데이터수집 및 탐색/data/review_data/df2_형태소분석.csv')
